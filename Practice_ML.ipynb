# %% [markdown]
# <a href="https://colab.research.google.com/github/SrivaniJayanthi/DataPirates_FreeRtos/blob/main/Practice_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = [['apples', 10, 240], ['orange', 15, 150], ['grapes', 20, 200], ['pineapple', 40, 200]]
df1 = pd.DataFrame(data, columns = ['Fruit_name', 'Quantity', 'Unit_price'])
df1
# Out:
#   Fruit_name  Quantity  Unit_price
# 0     apples        10         240
# 1     orange        15         150
# 2     grapes        20         200
# 3  pineapple        40         200

# %%
df1.shape #No of rows and columns in a tuple
# Out:
# (4, 3)

# %%
df1.info() #No of null values will be given
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fruit_name  4 non-null      object
#  1   Quantity    4 non-null      int64
#  2   Unit_price  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df1.describe() #It gives you a 5 number summary(mean, std, 25-quatile1, 50-quatile2, 75-quatile3) only for numbers and not for objects/discrete data types
# Out:
#         Quantity  Unit_price
# count   4.000000    4.000000
# mean   21.250000  197.500000
# std    13.149778   36.855574
# min    10.000000  150.000000
# 25%    13.750000  187.500000
# 50%    17.500000  200.000000
# 75%    25.000000  210.000000
# max    40.000000  240.000000

# %% [markdown]
# **Sources of the data sets on the internet:**
#
#
# 1.   UCL
# 2.   Kaggle
# 3.   GitHub

# %% [markdown]
# **Various Names:**
# 1. Independent variables/predictor variables/input features - sl, sw, pl, pw
# 2. Dependent variables/predictor variables/output variables = class

# %%
iris = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df = pd.read_csv(iris, sep=',', names = names)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.head(15)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.tail(15)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# ...

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 142           5.8          2.7           5.1          1.9   Iris-virginica
# 45            4.8          3.0           1.4          0.3      Iris-setosa
# 111           6.4          2.7           5.3          1.9   Iris-virginica
# 143           6.8          3.2           5.9          2.3   Iris-virginica
# 71            6.1          2.8           4.0          1.3  Iris-versicolor

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **Functions:**
#
#
# 1.  df.columns()
# 2.  df.info()
# 3.  df.shape()
# 4.  df.head(n)
# 5.  df.tail(n)
# 6.  df.sample()
# 7.  df.dtypes()
# 8.  df[col.name].dtypes

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['class'].nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
df['petal_length'] #one single column is series
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %% [markdown]
# 1. df.loc() = for any index type(int/object)
# 2. df.iloc() = for only int indexes
